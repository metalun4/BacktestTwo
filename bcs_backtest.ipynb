# %%
import Backtester as bt
import Strategy as strat

# %%
spy_backtest = bt.Backtester('5000', 'SPY', 2010-1-1, '2019-12-31')

# %%
spy_backtest.main()
# Out:
# Portfolio current value: $10011.39
